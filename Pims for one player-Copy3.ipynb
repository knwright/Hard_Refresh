# %%
import urllib.request
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import lxml.html as lh

# %%
urls =[
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=1',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=2',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=3',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=4',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=5',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=6',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=7',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=8',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=9',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=10',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=11',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=12',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=13',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=14',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=15',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=16',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=17',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=18',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=19',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=20',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=21',
'https://www.foxsports.com/nhl/stats?season=2018&category=PENALTIES&group=1&sort=1&time=0&pos=0&team=0&qual=1&sortOrder=0&page=22'

]

# %%
stats = []

for url in urls:
    page = urllib.request.urlopen(url)
    player_season_stats = pd.read_html(url)[0]
    stats.append(player_season_stats)
        
    soup=''
    page= ''
    name= ''
    player_season_stats = ''

# %%
stats
# Out:
# [                                           PENALTIES  GP  PEN  MIN  PIM  PIM/G
#  0                      1  Kane, Evander  Kane, E. SJ  75   47   37  153    2.0
#  1                         2  Cole, Ian  Cole, I. COL  71   35   25  115    1.6
#  2               2  Roussel, Antoine  Roussel, A. VAN  65   35   27  118    1.8
#  3                     2  Wilson, Tom  Wilson, T. WSH  63   35   24  128    2.0
#  4                  5  Coleman, Blake  Coleman, B. NJ  78   34   33   71    0.9
#  5                6  Marchand, Brad  Marchand, B. BOS  79   33   28   96    1.2
#  6                6  Zadorov, Nikita  Zadorov, N. COL  70   33   30   75    1.1
#  7                         6  Domi, Max  Domi, M. MTL  82   33   30   80    1.0
#  8               6  Paquette, Cedric  Paquette, C. TB  80   33   30   80    1.0
#  9               10  Giordano, Mark  Giordano, M. CGY  78   32   30   69    0.9
#  10                    10  Smith, Zack  Smith, Z. OTT  70   32   28   81    1.2
# ...
