# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import math

from matplotlib.pyplot import imshow
from PIL import Image, ImageDraw
import face_recognition

import urllib.request 

import pandas as pd

# %%
def load_image(path, url=False):
    if not url:
        return face_recognition.load_image_file(path)
    else:
        if path[-3:] == 'jpg' or  path[-3:] == 'peg':
            urllib.request.urlretrieve(path, 'tmp.jpg')
            return face_recognition.load_image_file('tmp.jpg')
        elif path[-3:] == 'png':
            urllib.request.urlretrieve(path, 'tmp.png')
            return face_recognition.load_image_file('tmp.png')
        else:
            print("Unknown image type")

# %%
def get_face_points(points, method='average', top='eyebrow'):
    width_left, width_right = points[0], points[16]
    
    if top == 'eyebrow':
        top_left = points[18]
        top_right = points[25]
        
    elif top == 'eyelid':
        top_left = points[37]
        top_right = points[43] 
        
    else:
        raise ValueError('Invalid top point, use either "eyebrow" or "eyelid"')
        
    bottom_left, bottom_right = points[50], points[52]
    
    if method == 'left':
        coords = (width_left[0], width_right[0], top_left[1], bottom_left[1])
        
    elif method == 'right':
        coords = (width_left[0], width_right[0], top_right[1], bottom_right[1])
        
    else:
        top_average = int((top_left[1] + top_right[1]) / 2)
        bottom_average = int((bottom_left[1] + bottom_right[1]) / 2)
        coords = (width_left[0], width_right[0], top_average, bottom_average)
        
    ## Move the line just a little above the top of the eye to the eyelid    
    if top == 'eyelid':
        coords = (coords[0], coords[1], coords[2] - 4, coords[3])
        
    return {'top_left' : (coords[0], coords[2]),
            'bottom_left' : (coords[0], coords[3]),
            'top_right' : (coords[1], coords[2]),
            'bottom_right' : (coords[1], coords[3])
           }

# %%
def good_picture_check(p, debug=False):
    ## To scale for picture size
    width_im = (p[16][0] - p[0][0]) / 100
    
    ## Difference in height between eyes
    eye_y_l = (p[37][1] + p[41][1]) / 2.0
    eye_y_r = (p[44][1] + p[46][1]) / 2.0
    eye_dif = (eye_y_r - eye_y_l) / width_im
    
    ## Difference top / bottom point nose 
    nose_dif = (p[30][0] - p[27][0]) / width_im
    
    ## Space between face-edge to eye, left vs. right
    left_space = p[36][0] - p[0][0]
    right_space = p[16][0] - p[45][0]
    space_ratio = left_space / right_space
    
    if debug:
        print(eye_dif, nose_dif, space_ratio)
    
    ## These rules are not perfect, determined by trying a bunch of "bad" pictures
    if eye_dif > 5 or nose_dif > 3.5 or space_ratio > 3:
        return False
    else:
        return True

# %%
def FWHR_calc(corners):
    width = corners['top_right'][0] - corners['top_left'][0]
    height = corners['bottom_left'][1] - corners['top_left'][1]
    return float(width) / float(height)

# %%
def show_box(image, corners):
    pil_image = Image.fromarray(image)
    w, h = pil_image.size
    
    ## Automatically determine width of the line depending on size of picture
    line_width = math.ceil(h / 100)
    
    d = ImageDraw.Draw(pil_image) 
    d.line([corners['bottom_left'], corners['top_left']], width = line_width)
    d.line([corners['bottom_left'], corners['bottom_right']], width = line_width)
    d.line([corners['top_left'], corners['top_right']], width = line_width)
    d.line([corners['top_right'], corners['bottom_right']], width = line_width)
    
    imshow(pil_image)

# %%
def get_fwhr(image_path, url=False, show=True, method='average', top='eyelid'):
    image = load_image(image_path, url)
    landmarks = face_recognition.api._raw_face_landmarks(image)
    landmarks_as_tuples = [(p.x, p.y) for p in landmarks[0].parts()]
    
    if good_picture_check(landmarks_as_tuples): 
        corners = get_face_points(landmarks_as_tuples, method=method, top = top)
        fwh_ratio = FWHR_calc(corners)
png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3114995.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3024837.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/2501067.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/2591151.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3025540.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3042020.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3067862.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3666.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3024784.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3025616.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3946.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5647.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3067858.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3114747.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3042044.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/2300267.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3101.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5479.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/2563053.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5034.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5542.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/2970615.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5118.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3069440.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3025608.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/4046946.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3620.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5646.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/1202.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3095330.png',
'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/5075.png'
]

# %%
for guy_url in guy_urls:
#guy_url = 'https://a.espncdn.com/combiner/i?img=/i/headshots/nhl/players/full/3025590.png'
    get_fwhr(guy_url, url=True)
# Out:
# Looking at a Hockey Player's face.....
# -----------------------------------------------
# Player Number
# 3025590
# His facial width to height ratio is:
# 2.1587301587301586
# -----------------------------------------------
# Looking at a Hockey Player's face.....
# -----------------------------------------------
# Player Number
# 3042080
# His facial width to height ratio is:
# 2.0121951219512195
# -----------------------------------------------
# Looking at a Hockey Player's face.....
# -----------------------------------------------
# Player Number
# 4294651
# His facial width to height ratio is:
# 2.0
# -----------------------------------------------
# Looking at a Hockey Player's face.....
# -----------------------------------------------
# Player Number
# 4267976
# His facial width to height ratio is:
# 2.375
# -----------------------------------------------
# Looking at a Hockey Player's face.....
# -----------------------------------------------
# Player Number
# 5757
# ...

# %%
print(player)
print(fwhr)
# Out:
# ['3025590', '3042080', '4294651', '4267976', '5757', '3899933', '3669', '2179', '3114744', '2563065', '4063433', '3735', '3151784', '3891922', '2306', '2976840', '2562618', '2389', '2339', '1671', '3506', '4024879', '3069394', '3041969', '3387', '5366', '5185', '5116', '3041995', '3114999', '2562609', '2563076', '3042092', '3899938', '5315', '5181', '4991', '4063401', '3649', '4233563', '2590752', '3042021', '5657', '3759', '3655', '3042062', '3067879', '2976842', '3042085', '5430', '1183', '3998', '3257', '3042003', '5526', '3249', '2563074', '5560', '2304599', '3149612', '3042040', '4233536', '3114754', '5759', '2590751', '3069352', '3993', '2328', '2562625', '3384', '3866', '4272107', '3760', '3115033', '3904091', '2147', '4024933', '2563085', '2378', '3069396', '3114743', '5172', '3900260', '2975', '2593315', '2952877', '2290', '3067505', '2562600', '2970689', '2334821', '4924', '2564164', '5079', '3047', '3242', '5223', '4927', '3648', '2968772', '3149649', '5831', '2563044', '2
# ...

# %%
data = {'player_number':player,
        'fWHR':fwhr}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   player_number      fWHR
# 0       3025590  2.158730
# 1       3042080  2.012195
# 2       4294651  2.000000
# 3       4267976  2.375000
# 4          5757  1.986842

# %%
df.sort_values(by='fWHR', ascending=False)
df.head(20)
# Out:
#    player_number      fWHR
# 0        3025590  2.158730
# 1        3042080  2.012195
# 2        4294651  2.000000
# 3        4267976  2.375000
# 4           5757  1.986842
# 5        3899933  2.026667
# 6           3669  2.238095
# 7           2179  2.103896
# 8        3114744  2.258065
# 9        2563065  2.115942
# 10       4063433  2.459016
# 11          3735  2.183099
# 12       3151784  1.987342
# 13       3891922  1.884615
# 14          2306  2.000000
# 15       2976840  2.014085
# 16       2562618  2.225352
# 17          2389  1.986667
# 18          2339  2.185714
# 19          1671  2.025974

# %%
df['scaled'] = [x/df.fWHR.max() for x in df.fWHR]

# %%
head = df.head()
tail = df.tail()

print(head)
# Out:
#   player_number      fWHR    scaled
# 0       3025590  2.158730  0.807688
# 1       3042080  2.012195  0.752862
# 2       4294651  2.000000  0.748299
# 3       4267976  2.375000  0.888605
# 4          5757  1.986842  0.743376

# %%
df.to_csv('fwhr.csv')
